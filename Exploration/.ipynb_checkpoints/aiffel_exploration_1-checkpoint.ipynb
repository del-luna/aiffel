# %%
import os
import glob
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow import keras
from tensorflow.keras import layers

# %%
import shutil

'''
다른사람의 파일네임이 0~99.jpg인 경우가 많아
데이터셋을 합칠 때 사용하는 file move 함수 구현
'''


def file_move(path1, path2):
    start = path1
    destination = path2
    
    get_files = os.listdir(start)
    idx=100
    for f in get_files:
        shutil.move(start + f, destination + f'{idx}.jpg')
        idx+=1

# %%
train_dir = './data/rock_scissor_paper/train/'
test_dir = './data/rock_scissor_paper/test/'

# %%
file_move(test_dir+'paper/', train_dir+'paper/')
file_move(test_dir+'rock/', train_dir+'rock/')
file_move(test_dir+'scissor/', train_dir+'scissor/')

# %%
#data load
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '../../../data/rock_scissor_paper/train',
    shuffle=True,
    seed=42,
    image_size=(224, 224),
    batch_size=10)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '../../../data/rock_scissor_paper/test',
    seed=42,
    image_size=(224,224),
    batch_size=10
)
# Out:
# Found 600 files belonging to 3 classes.
# Found 300 files belonging to 3 classes.

# %% [markdown]
# ## Sequential layer에 data augmentation 추가하기

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(224, 224),
  layers.experimental.preprocessing.Rescaling(1./255)
])

data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.5),
    layers.experimental.preprocessing.RandomZoom(.2,.2)
])

# %%
ex_img, ex_label = next(iter(train_ds))

plt.figure(figsize=(10, 10))
for i in range(9):
    resize_img = resize_and_rescale(ex_img)
    augmented_image = data_augmentation(resize_img)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_image[0])
    plt.axis("off")

# %% [markdown]
# ## Train-Test Split

# %%
mixed_ds = train_ds.concatenate(test_ds)
mixed_list = list(mixed_ds.batch(900).as_numpy_iterator())

inputs = mixed_list[0][0].reshape(-1,224,224,3)
targets = mixed_list[0][1].reshape(-1)

# %%
x_train, x_valid, y_train, y_valid = train_test_split(inputs, targets, test_size=0.2, shuffle=True, random_state=42)
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.25, shuffle=True, random_state=42)

# %%
# 6: 2: 2
print(f'len of x_train: {len(x_train)}')
print(f'len of x_valid: {len(x_valid)}')
print(f'len of x_test: {len(x_test)}')
# Out:
# len of x_train: 540
# len of x_valid: 180
# len of x_test: 180

# %%
#MaxPool2D 대신 strides=2 사용한 모델

model = tf.keras.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(16, 3, strides=2, padding='same', activation='relu'),
    #layers.BatchNormalization(),
    layers.Conv2D(32, 3, strides=2, padding='same', activation='relu'),
    #layers.BatchNormalization(),
    layers.Conv2D(64, 3, strides=2, padding='same', activation='relu'),
    #layers.BatchNormalization(),
    layers.Conv2D(128, 3, strides=2, padding='same', activation='relu'),
    #layers.BatchNormalization(),
    layers.Conv2D(256, 3, strides=2, padding='same', activation='relu'),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(256, activation='relu'),
    layers.Dense(3, activation='softmax')
])

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

epochs=20
history = model.fit(
    x_train, y_train,
    epochs=epochs,
    validation_data=(x_valid,y_valid))
model.summary()
# Out:
# Epoch 1/20
# 17/17 [==============================] - 5s 71ms/step - loss: 1.1005 - accuracy: 0.3296 - val_loss: 1.0824 - val_accuracy: 0.4667
# Epoch 2/20
# 17/17 [==============================] - 0s 29ms/step - loss: 0.9247 - accuracy: 0.5889 - val_loss: 0.6583 - val_accuracy: 0.6778
# Epoch 3/20
# 17/17 [==============================] - 0s 29ms/step - loss: 0.7399 - accuracy: 0.6574 - val_loss: 0.5581 - val_accuracy: 0.7500
# Epoch 4/20
# 17/17 [==============================] - 0s 29ms/step - loss: 0.7047 - accuracy: 0.6926 - val_loss: 0.6171 - val_accuracy: 0.7667
# Epoch 5/20
# 17/17 [==============================] - 0s 28ms/step - loss: 0.6228 - accuracy: 0.7185 - val_loss: 0.5246 - val_accuracy: 0.7778
# Epoch 6/20
# 17/17 [==============================] - 0s 29ms/step - loss: 0.5911 - accuracy: 0.7259 - val_loss: 0.4794 - val_accuracy: 0.7833
# Epoch 7/20
# 17/17 [==============================] - 0s 29ms/step - loss: 0.5122 - accuracy: 0.8056 - val_loss: 0.3736 - val_accuracy: 0.8556
# Epoch 8/20
# 17/17 [==============================] - 0s 29ms/step - loss: 0.5525 - accuracy: 0.7667 - val_loss: 0.3948 - val_accuracy: 0.8611
# Epoch 9/20
# 17/17 [==============================] - 0s 29ms/step - loss: 0.5039 - accuracy: 0.7870 - val_loss: 0.5204 - val_accuracy: 0.7389
# Epoch 10/20
# 17/17 [==============================] - 0s 29ms/step - loss: 0.4466 - accuracy: 0.8407 - val_loss: 0.3002 - val_accuracy: 0.9000
# Epoch 11/20
# 17/17 [==============================] - 0s 29ms/step - loss: 0.3667 - accuracy: 0.8611 - val_loss: 0.2739 - val_accuracy: 0.9111
# Epoch 12/20
# 17/17 [==============================] - 0s 29ms/step - loss: 0.4179 - accuracy: 0.8444 - val_loss: 0.5026 - val_accuracy: 0.7889
# Epoch 13/20
# 17/17 [==============================] - 0s 29ms/step - loss: 0.3649 - accuracy: 0.8630 - val_loss: 0.2602 - val_accuracy: 0.9111
# Epoch 14/20
# 17/17 [==============================] - 0s 29ms/step - loss: 0.3720 - accuracy: 0.8926 - val_loss: 0.3112 - val_accuracy: 0.8944
# Epoch 15/20
# 17/17 [==============================] - 0s 29ms/step - loss: 0.2718 - accuracy: 0.9074 - val_loss: 0.1745 - val_accuracy: 0.9667
# Epoch 16/20
# 17/17 [==============================] - 0s 29ms/step - loss: 0.2261 - accuracy: 0.9259 - val_loss: 0.1591 - val_accuracy: 0.9389
# Epoch 17/20
# 17/17 [==============================] - 0s 29ms/step - loss: 0.2387 - accuracy: 0.9167 - val_loss: 0.2069 - val_accuracy: 0.9167
# Epoch 18/20
# 17/17 [==============================] - 0s 29ms/step - loss: 0.1438 - accuracy: 0.9500 - val_loss: 0.1883 - val_accuracy: 0.9333
# Epoch 19/20
# 17/17 [==============================] - 0s 29ms/step - loss: 0.1955 - accuracy: 0.9296 - val_loss: 0.2191 - val_accuracy: 0.9000
# Epoch 20/20
# 17/17 [==============================] - 0s 29ms/step - loss: 0.1844 - accuracy: 0.9407 - val_loss: 0.1945 - val_accuracy: 0.9389
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 224, 224, 3)       0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 112, 112, 16)      448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 56, 56, 32)        4640
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 256)         295168
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 12544)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               3211520
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 3,604,899
# Trainable params: 3,604,899
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss, acc = model.evaluate(x_test,y_test, batch_size=30)
print(f'loss: {loss:.3f}, accuracy: {acc:.3f}')
# Out:
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1803 - accuracy: 0.9111
# loss: 0.180, accuracy: 0.911

# %%
#MaxPool2D 사용한 모델

model = tf.keras.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    #layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    #layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    #layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Conv2D(128, 3, padding='same', activation='relu'),
    #layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Conv2D(256, 3, padding='same', activation='relu'),
    #layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(256, activation='relu'),
    layers.Dense(3, activation='softmax')
])

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

epochs=20
history = model.fit(
    x_train, y_train,
    epochs=epochs,
    validation_data=(x_valid,y_valid))
model.summary()
# Out:
# Epoch 1/20
# 17/17 [==============================] - 2s 61ms/step - loss: 1.1288 - accuracy: 0.3463 - val_loss: 1.1037 - val_accuracy: 0.3167
# Epoch 2/20
# 17/17 [==============================] - 1s 42ms/step - loss: 1.1014 - accuracy: 0.3315 - val_loss: 1.0982 - val_accuracy: 0.3667
# Epoch 3/20
# 17/17 [==============================] - 1s 41ms/step - loss: 1.0986 - accuracy: 0.3630 - val_loss: 1.0968 - val_accuracy: 0.3778
# Epoch 4/20
# 17/17 [==============================] - 1s 42ms/step - loss: 1.0884 - accuracy: 0.3796 - val_loss: 1.0667 - val_accuracy: 0.4500
# Epoch 5/20
# 17/17 [==============================] - 1s 41ms/step - loss: 1.0721 - accuracy: 0.3926 - val_loss: 0.9818 - val_accuracy: 0.5167
# Epoch 6/20
# 17/17 [==============================] - 1s 41ms/step - loss: 0.9790 - accuracy: 0.5019 - val_loss: 0.9437 - val_accuracy: 0.5056
# Epoch 7/20
# 17/17 [==============================] - 1s 41ms/step - loss: 0.8779 - accuracy: 0.5463 - val_loss: 0.7040 - val_accuracy: 0.7722
# Epoch 8/20
# 17/17 [==============================] - 1s 42ms/step - loss: 0.7194 - accuracy: 0.6907 - val_loss: 0.9065 - val_accuracy: 0.5278
# Epoch 9/20
# 17/17 [==============================] - 1s 41ms/step - loss: 0.7556 - accuracy: 0.6704 - val_loss: 0.5303 - val_accuracy: 0.8167
# Epoch 10/20
# 17/17 [==============================] - 1s 41ms/step - loss: 0.5128 - accuracy: 0.8167 - val_loss: 0.5689 - val_accuracy: 0.8000
# Epoch 11/20
# 17/17 [==============================] - 1s 41ms/step - loss: 0.5970 - accuracy: 0.7778 - val_loss: 0.6500 - val_accuracy: 0.7167
# Epoch 12/20
# 17/17 [==============================] - 1s 41ms/step - loss: 0.6441 - accuracy: 0.7574 - val_loss: 0.5176 - val_accuracy: 0.7722
# Epoch 13/20
# 17/17 [==============================] - 1s 41ms/step - loss: 0.4914 - accuracy: 0.8093 - val_loss: 0.5342 - val_accuracy: 0.7444
# Epoch 14/20
# 17/17 [==============================] - 1s 42ms/step - loss: 0.4100 - accuracy: 0.8537 - val_loss: 0.3460 - val_accuracy: 0.9000
# Epoch 15/20
# 17/17 [==============================] - 1s 41ms/step - loss: 0.3581 - accuracy: 0.8593 - val_loss: 0.4378 - val_accuracy: 0.8333
# Epoch 16/20
# 17/17 [==============================] - 1s 42ms/step - loss: 0.3729 - accuracy: 0.8426 - val_loss: 0.3739 - val_accuracy: 0.8389
# Epoch 17/20
# 17/17 [==============================] - 1s 42ms/step - loss: 0.3713 - accuracy: 0.8500 - val_loss: 0.2879 - val_accuracy: 0.8722
# Epoch 18/20
# 17/17 [==============================] - 1s 41ms/step - loss: 0.4094 - accuracy: 0.8370 - val_loss: 0.2801 - val_accuracy: 0.9167
# Epoch 19/20
# 17/17 [==============================] - 1s 42ms/step - loss: 0.2724 - accuracy: 0.8926 - val_loss: 0.2533 - val_accuracy: 0.9278
# Epoch 20/20
# 17/17 [==============================] - 1s 40ms/step - loss: 0.1807 - accuracy: 0.9333 - val_loss: 0.1786 - val_accuracy: 0.9500
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 224, 224, 3)       0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 224, 224, 16)      448
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 112, 112, 32)      4640
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 56, 56, 64)        18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 14, 14, 256)       295168
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12544)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               3211520
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 3,604,899
# Trainable params: 3,604,899
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss, acc = model.evaluate(x_test,y_test, batch_size=30)
print(f'loss: {loss:.3f}, accuracy: {acc:.3f}')
# Out:
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1664 - accuracy: 0.9500
# loss: 0.166, accuracy: 0.950

# %% [markdown]
# ## Pretrained Model 돌려보기

# %% [markdown]
# ## ResNet50
#
# - data size에 비해 모델의 사이즈가 너무 큼

# %%
from tensorflow.keras.applications import ResNet50

model = ResNet50(include_top=True, weights=None, input_shape=(224, 224, 3), pooling=max, classes=3)

# %%
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

epochs=5
history = model.fit(
    x_train, y_train,
    epochs=epochs,
    validation_data=(x_valid,y_valid))
# Out:
# Epoch 1/5
# 17/17 [==============================] - 22s 645ms/step - loss: 3.7965 - accuracy: 0.3574 - val_loss: 1729.5861 - val_accuracy: 0.3222
# Epoch 2/5
# 17/17 [==============================] - 5s 312ms/step - loss: 0.6995 - accuracy: 0.7685 - val_loss: 1855.6049 - val_accuracy: 0.3222
# Epoch 3/5
# 17/17 [==============================] - 5s 312ms/step - loss: 0.2626 - accuracy: 0.8981 - val_loss: 565.8265 - val_accuracy: 0.3222
# Epoch 4/5
# 17/17 [==============================] - 5s 312ms/step - loss: 0.1353 - accuracy: 0.9500 - val_loss: 76.9586 - val_accuracy: 0.3222
# Epoch 5/5
# 17/17 [==============================] - 5s 312ms/step - loss: 0.0368 - accuracy: 0.9907 - val_loss: 17.0772 - val_accuracy: 0.2833

# %%
loss, acc = model.evaluate(x_test,y_test, batch_size=30)
print(f'loss: {loss:.3f}, accuracy: {acc:.3f}')
# Out:
# 6/6 [==============================] - 2s 73ms/step - loss: 17.9662 - accuracy: 0.3000
# loss: 17.966, accuracy: 0.300

# %%
del model
